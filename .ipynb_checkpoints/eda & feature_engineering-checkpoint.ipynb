# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

from pylab import rcParams
rcParams['figure.figsize'] = 12,8
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import os

import itertools 
from datetime import datetime, timedelta

import matplotlib.pyplot as plt

# %%
import re

# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

import phik

# %%
path = "/masters_diploma/raw_data/open-meteo-50.44N30.48E188m.csv"

df = pd.read_csv(path, header=2)

# %%
df['time'] = df['time'].apply(lambda x: pd.to_datetime(pd.Timestamp(x).strftime('%Y-%m-%d %H:%M:%S')))
df = df.set_index('time')
df.index.name = 'date'
df
# Out:
#                      temperature_2m (°C)  relative_humidity_2m (%)  \
# date
# 2020-01-01 00:00:00                  1.5                        94
# 2020-01-01 01:00:00                  1.0                        95
# 2020-01-01 02:00:00                  1.5                        93
# 2020-01-01 03:00:00                  1.5                        92
# 2020-01-01 04:00:00                  1.0                        94
# ...                                  ...                       ...
# 2025-01-17 19:00:00                  1.2                        97
# 2025-01-17 20:00:00                  1.2                        98
# 2025-01-17 21:00:00                  1.1                        98
# 2025-01-17 22:00:00                  1.1                        98
# 2025-01-17 23:00:00                  1.1                        98
#
#                      dew_point_2m (°C)  precipitation (mm)  rain (mm)  \
# date
# 2020-01-01 00:00:00                0.6                 0.6        0.1
# 2020-01-01 01:00:00                0.4                 0.3        0.3
# 2020-01-01 02:00:00                0.5                 0.2        0.2
# 2020-01-01 03:00:00                0.4                 0.1        0.1
# 2020-01-01 04:00:00                0.2                 0.2        0.2
# ...                                ...                 ...        ...
# 2025-01-17 19:00:00                0.8                 0.0        0.0
# 2025-01-17 20:00:00                0.8                 0.1        0.1
# 2025-01-17 21:00:00                0.8                 0.0        0.0
# 2025-01-17 22:00:00                0.8                 0.0        0.0
# 2025-01-17 23:00:00                0.8                 0.0        0.0
#
#                      snowfall (cm)  weather_code (wmo code)  \
# date
# 2020-01-01 00:00:00           0.35                       73
# 2020-01-01 01:00:00           0.00                       51
# 2020-01-01 02:00:00           0.00                       51
# 2020-01-01 03:00:00           0.00                       51
# 2020-01-01 04:00:00           0.00                       51
# ...                            ...                      ...
# 2025-01-17 19:00:00           0.00                        3
# 2025-01-17 20:00:00           0.00                       51
# 2025-01-17 21:00:00           0.00                        3
# 2025-01-17 22:00:00           0.00                        3
# 2025-01-17 23:00:00           0.00                        3
#
#                      pressure_msl (hPa)  surface_pressure (hPa)  \
# date
# 2020-01-01 00:00:00              1009.8                   986.5
# 2020-01-01 01:00:00              1010.4                   987.1
# 2020-01-01 02:00:00              1010.8                   987.5
# 2020-01-01 03:00:00              1011.7                   988.4
# 2020-01-01 04:00:00              1012.8                   989.4
# ...                                 ...                     ...
# 2025-01-17 19:00:00              1027.7                  1004.0
# 2025-01-17 20:00:00              1028.0                  1004.3
# 2025-01-17 21:00:00              1028.1                  1004.4
# 2025-01-17 22:00:00              1028.0                  1004.3
# 2025-01-17 23:00:00              1028.0                  1004.3
#
#                      cloud_cover (%)  wind_speed_10m (km/h)  \
# date
# 2020-01-01 00:00:00               97                   23.2
# 2020-01-01 01:00:00              100                   25.1
# 2020-01-01 02:00:00              100                   26.6
# 2020-01-01 03:00:00              100                   26.7
# 2020-01-01 04:00:00              100                   25.5
# ...                              ...                    ...
# 2025-01-17 19:00:00              100                   13.5
# 2025-01-17 20:00:00              100                   13.5
# 2025-01-17 21:00:00              100                   13.1
# 2025-01-17 22:00:00              100                   12.9
# 2025-01-17 23:00:00              100                   13.3
#
#                      wind_direction_10m (°)  is_day ()  sunshine_duration (s)
# date
# 2020-01-01 00:00:00                     296          0                    0.0
# 2020-01-01 01:00:00                     302          0                    0.0
# 2020-01-01 02:00:00                     311          0                    0.0
# 2020-01-01 03:00:00                     316          0                    0.0
# 2020-01-01 04:00:00                     316          0                    0.0
# ...                                     ...        ...                    ...
# 2025-01-17 19:00:00                     308          0                    0.0
# 2025-01-17 20:00:00                     308          0                    0.0
# 2025-01-17 21:00:00                     304          0                    0.0
# 2025-01-17 22:00:00                     302          0                    0.0
# 2025-01-17 23:00:00                     298          0                    0.0
#
# [44256 rows x 14 columns]

# %%
plt.scatter(x='dew_point_2m (°C)', y='temperature_2m (°C)', data=df)

# %%
# plt.plot(df['temperature_2m (°C)'])

# %%
df.columns = [i.split(" (")[0] for i in df.columns]
df.columns = [re.split(r"_\d+", i)[0] if i.endswith('m') else i for i in df.columns]
df.columns
# Out:
# Index(['temperature', 'relative_humidity', 'dew_point', 'precipitation',
#        'rain', 'snowfall', 'weather_code', 'pressure_msl', 'surface_pressure',
#        'cloud_cover', 'wind_speed', 'wind_direction', 'is_day',
#        'sunshine_duration'],
#       dtype='object')

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df['hour'] = df.index.hour
df['week_day'] = df.index.day_of_week
df['year_day'] = df.index.day_of_year

# %%
for feature in ['temperature', 'relative_humidity', 'dew_point', 'precipitation', 'rain', 'snowfall', 'pressure_msl', 
                'surface_pressure', 'cloud_cover', 'wind_speed', 'wind_direction', 'sunshine_duration']:
    for window in [3, 5, 7]:

        close_agg = pd.DataFrame(round(df.groupby('hour')[f'{feature}'].rolling(window=window, closed='left').agg(
            ('max', 'min', 'mean')
        )))
        close_agg.columns = [f'{feature}_max_{window}_days', f'{feature}_min_{window}_days', f'{feature}_mean_{window}_days']
        day_mean = close_agg.reset_index()[['date', f'{feature}_max_{window}_days', f'{feature}_min_{window}_days', f'{feature}_mean_{window}_days']]

        df = df.reset_index().merge(day_mean, on='date').set_index("date")
     
    
    for window in [3, 5, 7]:

        close_agg = pd.DataFrame(round(df.groupby('week_day')[f'{feature}'].rolling(window=window, closed='left').agg(
            ('max', 'min', 'mean')
        )))
        close_agg.columns = [f'{feature}_max_{window}_weeks', f'{feature}_min_{window}_weeks', f'{feature}_mean_{window}_weeks']
        day_mean = close_agg.reset_index()[['date', f'{feature}_max_{window}_weeks', f'{feature}_min_{window}_weeks', f'{feature}_mean_{window}_weeks']]

        df = df.reset_index().merge(day_mean, on='date').set_index("date")
    
    
    for window in [3, 4]:

        close_agg = pd.DataFrame(round(df.groupby('year_day')[f'{feature}'].rolling(window=window, closed='left').agg(
            ('max', 'min', 'mean')
        )))
        close_agg.columns = [f'{feature}_max_{window}_years', f'{feature}_min_{window}_years', f'{feature}_mean_{window}_years']
        day_mean = close_agg.reset_index()[['date', f'{feature}_max_{window}_years', f'{feature}_min_{window}_years', f'{feature}_mean_{window}_years']]

        df = df.reset_index().merge(day_mean, on='date').set_index("date")
        
        
    for h in [24, 48, 72]:
        df[f'{feature}_lag_{h}'] = df[[f'{feature}']].shift(h)

# %%
df = df[:df.index.date[-1]].bfill()
df
# Out:
#                      temperature  relative_humidity  dew_point  precipitation  \
# date
# 2020-01-01 00:00:00          1.5                 94        0.6            0.6
# 2020-01-01 01:00:00          1.0                 95        0.4            0.3
# 2020-01-01 02:00:00          1.5                 93        0.5            0.2
# 2020-01-01 03:00:00          1.5                 92        0.4            0.1
# 2020-01-01 04:00:00          1.0                 94        0.2            0.2
# ...                          ...                ...        ...            ...
# 2025-01-16 20:00:00          0.7                 92       -0.4            0.0
# 2025-01-16 21:00:00          0.7                 91       -0.5            0.0
# 2025-01-16 22:00:00          0.8                 90       -0.6            0.0
# 2025-01-16 23:00:00          0.6                 90       -0.8            0.0
# 2025-01-17 00:00:00          0.6                 89       -1.0            0.0
#
#                      rain  snowfall  weather_code  pressure_msl  \
# date
# 2020-01-01 00:00:00   0.1      0.35            73        1009.8
# 2020-01-01 01:00:00   0.3      0.00            51        1010.4
# 2020-01-01 02:00:00   0.2      0.00            51        1010.8
# 2020-01-01 03:00:00   0.1      0.00            51        1011.7
# 2020-01-01 04:00:00   0.2      0.00            51        1012.8
# ...                   ...       ...           ...           ...
# 2025-01-16 20:00:00   0.0      0.00             3        1030.3
# 2025-01-16 21:00:00   0.0      0.00             3        1030.3
# 2025-01-16 22:00:00   0.0      0.00             3        1030.0
# 2025-01-16 23:00:00   0.0      0.00             3        1029.6
# 2025-01-17 00:00:00   0.0      0.00             3        1029.4
#
#                      surface_pressure  cloud_cover  ...  \
# date                                                ...
# 2020-01-01 00:00:00             986.5           97  ...
# 2020-01-01 01:00:00             987.1          100  ...
# 2020-01-01 02:00:00             987.5          100  ...
# 2020-01-01 03:00:00             988.4          100  ...
# 2020-01-01 04:00:00             989.4          100  ...
# ...                               ...          ...  ...
# 2025-01-16 20:00:00            1006.5          100  ...
# 2025-01-16 21:00:00            1006.5          100  ...
# 2025-01-16 22:00:00            1006.2           97  ...
# 2025-01-16 23:00:00            1005.8           88  ...
# 2025-01-17 00:00:00            1005.6          100  ...
#
#                      sunshine_duration_mean_7_weeks  \
# date
# 2020-01-01 00:00:00                             0.0
# 2020-01-01 01:00:00                             0.0
# 2020-01-01 02:00:00                             0.0
# 2020-01-01 03:00:00                             0.0
# 2020-01-01 04:00:00                             0.0
# ...                                             ...
# 2025-01-16 20:00:00                             0.0
# 2025-01-16 21:00:00                             0.0
# 2025-01-16 22:00:00                             0.0
# 2025-01-16 23:00:00                             0.0
# 2025-01-17 00:00:00                             0.0
#
#                      sunshine_duration_max_3_years  \
# date
# 2020-01-01 00:00:00                            0.0
# 2020-01-01 01:00:00                            0.0
# 2020-01-01 02:00:00                            0.0
# 2020-01-01 03:00:00                            0.0
# 2020-01-01 04:00:00                            0.0
# ...                                            ...
# 2025-01-16 20:00:00                            0.0
# 2025-01-16 21:00:00                            0.0
# 2025-01-16 22:00:00                            0.0
# 2025-01-16 23:00:00                            0.0
# 2025-01-17 00:00:00                            0.0
#
#                      sunshine_duration_min_3_years  \
# date
# 2020-01-01 00:00:00                            0.0
# 2020-01-01 01:00:00                            0.0
# 2020-01-01 02:00:00                            0.0
# 2020-01-01 03:00:00                            0.0
# 2020-01-01 04:00:00                            0.0
# ...                                            ...
# 2025-01-16 20:00:00                            0.0
# 2025-01-16 21:00:00                            0.0
# 2025-01-16 22:00:00                            0.0
# 2025-01-16 23:00:00                            0.0
# 2025-01-17 00:00:00                            0.0
#
#                      sunshine_duration_mean_3_years  \
# date
# 2020-01-01 00:00:00                             0.0
# 2020-01-01 01:00:00                             0.0
# 2020-01-01 02:00:00                             0.0
# 2020-01-01 03:00:00                             0.0
# 2020-01-01 04:00:00                             0.0
# ...                                             ...
# 2025-01-16 20:00:00                             0.0
# 2025-01-16 21:00:00                             0.0
# 2025-01-16 22:00:00                             0.0
# 2025-01-16 23:00:00                             0.0
# 2025-01-17 00:00:00                             0.0
#
#                      sunshine_duration_max_4_years  \
# date
# 2020-01-01 00:00:00                            0.0
# 2020-01-01 01:00:00                            0.0
# 2020-01-01 02:00:00                            0.0
# 2020-01-01 03:00:00                            0.0
# 2020-01-01 04:00:00                            0.0
# ...                                            ...
# 2025-01-16 20:00:00                            0.0
# 2025-01-16 21:00:00                            0.0
# 2025-01-16 22:00:00                            0.0
# 2025-01-16 23:00:00                            0.0
# 2025-01-17 00:00:00                            0.0
#
#                      sunshine_duration_min_4_years  \
# date
# 2020-01-01 00:00:00                            0.0
# 2020-01-01 01:00:00                            0.0
# 2020-01-01 02:00:00                            0.0
# 2020-01-01 03:00:00                            0.0
# 2020-01-01 04:00:00                            0.0
# ...                                            ...
# 2025-01-16 20:00:00                            0.0
# 2025-01-16 21:00:00                            0.0
# 2025-01-16 22:00:00                            0.0
# 2025-01-16 23:00:00                            0.0
# 2025-01-17 00:00:00                            0.0
#
#                      sunshine_duration_mean_4_years  sunshine_duration_lag_24  \
# date
# 2020-01-01 00:00:00                             0.0                       0.0
# 2020-01-01 01:00:00                             0.0                       0.0
# 2020-01-01 02:00:00                             0.0                       0.0
# 2020-01-01 03:00:00                             0.0                       0.0
# 2020-01-01 04:00:00                             0.0                       0.0
# ...                                             ...                       ...
# 2025-01-16 20:00:00                             0.0                       0.0
# 2025-01-16 21:00:00                             0.0                       0.0
# 2025-01-16 22:00:00                             0.0                       0.0
# 2025-01-16 23:00:00                             0.0                       0.0
# 2025-01-17 00:00:00                             0.0                       0.0
#
#                      sunshine_duration_lag_48  sunshine_duration_lag_72
# date
# 2020-01-01 00:00:00                       0.0                       0.0
# 2020-01-01 01:00:00                       0.0                       0.0
# 2020-01-01 02:00:00                       0.0                       0.0
# 2020-01-01 03:00:00                       0.0                       0.0
# 2020-01-01 04:00:00                       0.0                       0.0
# ...                                       ...                       ...
# 2025-01-16 20:00:00                       0.0                       0.0
# 2025-01-16 21:00:00                       0.0                       0.0
# 2025-01-16 22:00:00                       0.0                       0.0
# 2025-01-16 23:00:00                       0.0                       0.0
# 2025-01-17 00:00:00                       0.0                       0.0
#
# [44233 rows x 344 columns]

# %%
df.describe()
# Out:
#         temperature  relative_humidity     dew_point  precipitation  \
# count  44233.000000       44233.000000  44233.000000   44233.000000
# mean       9.718776          73.379603      4.551518       0.074906
# std        9.725349          18.101165      7.938452       0.355299
# min      -23.000000          15.000000    -24.800000       0.000000
# 25%        1.400000          61.000000     -1.100000       0.000000
# 50%        9.000000          77.000000      4.400000       0.000000
# 75%       17.700000          89.000000     11.100000       0.000000
# max       35.600000         100.000000     24.900000      15.000000
#
#                rain      snowfall  weather_code  pressure_msl  \
# count  44233.000000  44233.000000  44233.000000  44233.000000
# mean       0.063208      0.008216     10.665521   1016.333455
# std        0.341207      0.065224     20.574718      8.650778
# min        0.000000      0.000000      0.000000    983.700000
# 25%        0.000000      0.000000      1.000000   1010.800000
# 50%        0.000000      0.000000      3.000000   1016.000000
# 75%        0.000000      0.000000      3.000000   1021.800000
# max       15.000000      3.640000     75.000000   1047.600000
#
#        surface_pressure   cloud_cover  ...  sunshine_duration_mean_7_weeks  \
# count      44233.000000  44233.000000  ...                    44233.000000
# mean         993.536943     65.710646  ...                     1091.978658
# std            8.304246     40.460430  ...                     1298.976019
# min          961.900000      0.000000  ...                        0.000000
# 25%          988.400000     22.000000  ...                        0.000000
# 50%          993.500000     93.000000  ...                      464.000000
# 75%          998.800000    100.000000  ...                     2086.000000
# max         1022.800000    100.000000  ...                     3600.000000
#
#        sunshine_duration_max_3_years  sunshine_duration_min_3_years  \
# count                   44233.000000                   44233.000000
# mean                     1389.135758                     800.984921
# std                      1698.237151                    1441.938371
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                      3600.000000                     498.000000
# max                      3600.000000                    3600.000000
#
#        sunshine_duration_mean_3_years  sunshine_duration_max_4_years  \
# count                    44233.000000                   44233.000000
# mean                      1091.978930                    1523.204937
# std                       1482.574335                    1720.870129
# min                          0.000000                       0.000000
# 25%                          0.000000                       0.000000
# 50%                          0.000000                       0.000000
# 75%                       2441.000000                    3600.000000
# max                       3600.000000                    3600.000000
#
#        sunshine_duration_min_4_years  sunshine_duration_mean_4_years  \
# count                   44233.000000                    44233.000000
# mean                      684.754233                     1093.058192
# std                      1356.887466                     1434.267678
# min                         0.000000                        0.000000
# 25%                         0.000000                        0.000000
# 50%                         0.000000                        0.000000
# 75%                         0.000000                     2430.000000
# max                      3600.000000                     3600.000000
#
#        sunshine_duration_lag_24  sunshine_duration_lag_48  \
# count              44233.000000              44233.000000
# mean                1091.979633               1091.862134
# std                 1600.864938               1600.846124
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                 3600.000000               3600.000000
# max                 3600.000000               3600.000000
#
#        sunshine_duration_lag_72
# count              44233.000000
# mean                1091.446391
# std                 1600.718487
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                 3600.000000
# max                 3600.000000
#
# [8 rows x 344 columns]

# %%
windows = [1, 2, 3]
features = {'temperature': 'temp'
            , 'relative_humidity': 'humid'
            , 'precipitation': 'precip'
            , 'surface_pressure': 'pres'
            , 'cloud_cover': 'cloud'
            , 'wind_speed': 'wspeed'
            , 'wind_direction': 'wdir'
            }

for feature, fname in features.items():
    
    df[f'mean_{fname}'] = _[feature]
    df.loc['2024-01-01':, f'mean_{fname}'] = None

    for date in df.loc['2024-01-01':,].index:

        date_range = []

        for year in range(2020, date.year):

            try:
                date_range += [pd.to_datetime(f"{year}-{date.month}-{date.day} {date.hour}:00")]

            except ValueError:
                continue


        date_range = [d for d in date_range if d in df.index]

        if len(date_range) > 0:
            df.loc[date, f'mean_{fname}'] = round(df.loc[date_range, feature].mean(), 2)

            
    for window in windows:

        df[f'new_mean_{fname}_{window * 2 + 1}_days'] = _[feature]
        df.loc['2024-01-01':, f'new_mean_{fname}_{window * 2 + 1}_days'] = None

        for date in df.loc['2024-01-01':,].index:

            date_range = []

            for year in range(2020, date.year):

                try:
                    centre_date = pd.to_datetime(f"{year}-{date.month}-{date.day} {date.hour}:00")
                    date_range += list(pd.date_range(centre_date-timedelta(days=window), 
                                                     centre_date+timedelta(days=window), freq='D'))

                except ValueError:
                    continue


            date_range = [d for d in date_range if d in df.index]

            if len(date_range) > 0:
                df.loc[date, f'new_mean_{fname}_{window * 2 + 1}_days'] = round(df.loc[date_range, feature].mean(), 2)
                

df
# Out:
#                      temperature  relative_humidity  dew_point  precipitation  \
# date
# 2020-01-01 00:00:00          1.5                 94        0.6            0.6
# 2020-01-01 01:00:00          1.0                 95        0.4            0.3
# 2020-01-01 02:00:00          1.5                 93        0.5            0.2
# 2020-01-01 03:00:00          1.5                 92        0.4            0.1
# 2020-01-01 04:00:00          1.0                 94        0.2            0.2
# ...                          ...                ...        ...            ...
# 2025-01-16 20:00:00          0.7                 92       -0.4            0.0
# 2025-01-16 21:00:00          0.7                 91       -0.5            0.0
# 2025-01-16 22:00:00          0.8                 90       -0.6            0.0
# 2025-01-16 23:00:00          0.6                 90       -0.8            0.0
# 2025-01-17 00:00:00          0.6                 89       -1.0            0.0
#
#                      rain  snowfall  weather_code  pressure_msl  \
# date
# 2020-01-01 00:00:00   0.1      0.35            73        1009.8
# 2020-01-01 01:00:00   0.3      0.00            51        1010.4
# 2020-01-01 02:00:00   0.2      0.00            51        1010.8
# 2020-01-01 03:00:00   0.1      0.00            51        1011.7
# 2020-01-01 04:00:00   0.2      0.00            51        1012.8
# ...                   ...       ...           ...           ...
# 2025-01-16 20:00:00   0.0      0.00             3        1030.3
# 2025-01-16 21:00:00   0.0      0.00             3        1030.3
# 2025-01-16 22:00:00   0.0      0.00             3        1030.0
# 2025-01-16 23:00:00   0.0      0.00             3        1029.6
# 2025-01-17 00:00:00   0.0      0.00             3        1029.4
#
#                      surface_pressure  cloud_cover  ...  \
# date                                                ...
# 2020-01-01 00:00:00             986.5           97  ...
# 2020-01-01 01:00:00             987.1          100  ...
# 2020-01-01 02:00:00             987.5          100  ...
# 2020-01-01 03:00:00             988.4          100  ...
# 2020-01-01 04:00:00             989.4          100  ...
# ...                               ...          ...  ...
# 2025-01-16 20:00:00            1006.5          100  ...
# 2025-01-16 21:00:00            1006.5          100  ...
# 2025-01-16 22:00:00            1006.2           97  ...
# 2025-01-16 23:00:00            1005.8           88  ...
# 2025-01-17 00:00:00            1005.6          100  ...
#
#                      new_mean_cloud_5_days  new_mean_cloud_7_days  \
# date
# 2020-01-01 00:00:00                    NaN                    NaN
# 2020-01-01 01:00:00                    NaN                    NaN
# 2020-01-01 02:00:00                    NaN                    NaN
# 2020-01-01 03:00:00                    NaN                    NaN
# 2020-01-01 04:00:00                    NaN                    NaN
# ...                                    ...                    ...
# 2025-01-16 20:00:00                  81.00                  85.26
# 2025-01-16 21:00:00                  79.96                  84.17
# 2025-01-16 22:00:00                  82.64                  83.94
# 2025-01-16 23:00:00                  81.20                  82.89
# 2025-01-17 00:00:00                  81.00                  83.11
#
#                      mean_wspeed  new_mean_wspeed_3_days  \
# date
# 2020-01-01 00:00:00          NaN                     NaN
# 2020-01-01 01:00:00          NaN                     NaN
# 2020-01-01 02:00:00          NaN                     NaN
# 2020-01-01 03:00:00          NaN                     NaN
# 2020-01-01 04:00:00          NaN                     NaN
# ...                          ...                     ...
# 2025-01-16 20:00:00        13.30                   14.69
# 2025-01-16 21:00:00        13.38                   14.24
# 2025-01-16 22:00:00        13.90                   14.63
# 2025-01-16 23:00:00        14.08                   14.62
# 2025-01-17 00:00:00        15.04                   14.48
#
#                      new_mean_wspeed_5_days  new_mean_wspeed_7_days  \
# date
# 2020-01-01 00:00:00                     NaN                     NaN
# 2020-01-01 01:00:00                     NaN                     NaN
# 2020-01-01 02:00:00                     NaN                     NaN
# 2020-01-01 03:00:00                     NaN                     NaN
# 2020-01-01 04:00:00                     NaN                     NaN
# ...                                     ...                     ...
# 2025-01-16 20:00:00                   14.36                   13.77
# 2025-01-16 21:00:00                   14.15                   13.45
# 2025-01-16 22:00:00                   14.42                   13.50
# 2025-01-16 23:00:00                   14.36                   13.58
# 2025-01-17 00:00:00                   13.93                   13.26
#
#                      mean_wdir  new_mean_wdir_3_days  new_mean_wdir_5_days  \
# date
# 2020-01-01 00:00:00        NaN                   NaN                   NaN
# 2020-01-01 01:00:00        NaN                   NaN                   NaN
# 2020-01-01 02:00:00        NaN                   NaN                   NaN
# 2020-01-01 03:00:00        NaN                   NaN                   NaN
# 2020-01-01 04:00:00        NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 2025-01-16 20:00:00      242.2                239.40                237.96
# 2025-01-16 21:00:00      242.2                237.40                240.76
# 2025-01-16 22:00:00      244.8                237.60                241.20
# 2025-01-16 23:00:00      249.8                238.73                242.60
# 2025-01-17 00:00:00      245.2                237.13                243.40
#
#                      new_mean_wdir_7_days
# date
# 2020-01-01 00:00:00                   NaN
# 2020-01-01 01:00:00                   NaN
# 2020-01-01 02:00:00                   NaN
# 2020-01-01 03:00:00                   NaN
# 2020-01-01 04:00:00                   NaN
# ...                                   ...
# 2025-01-16 20:00:00                240.80
# 2025-01-16 21:00:00                242.03
# 2025-01-16 22:00:00                241.89
# 2025-01-16 23:00:00                240.40
# 2025-01-17 00:00:00                240.86
#
# [44233 rows x 372 columns]

# %%
# for feature in features.keys():
    
#     corr_table = df.corr()[feature]
#     phik_corr_table = df.phik_matrix()[feature]

#     new_df = pd.concat([corr_table, phik_corr_table], axis=1)
#     new_df.columns = ['linear_corr_close', 'phik_corr_close']

#     fig = make_subplots(rows=1, cols=1, 
#                         subplot_titles=(f"Correlations with {feature.title()}"))

#     fig.add_trace(go.Bar(
#         y=new_df['linear_corr_close'],
#         x=new_df.index,
#         name='Linear Correlation',
#         marker_color="red"
#     ), row=1, col=1)

#     fig.add_trace(go.Bar(
#         y=new_df['phik_corr_close'],
#         x=new_df.index,
#         name='Phik Correlation',
#         marker_color="blue"
#     ), row=1, col=1)

#     fig.update_layout(
#         title=f'Correlations with {feature.title()}', 
#         xaxis_tickangle=-45,
#         width=1300,
#         height=1000,
#         hovermode="x"
#     )

#     fig.write_html(f'/masters_diploma/correlation_vizualizations/correlations_{feature}.html')

# %%
# for feature, fname in features.items():
    
#     fig = make_subplots(rows=1, cols=1, 
#                     subplot_titles=(f"Means of {feature.title()}"))


#     fig.add_trace(go.Scatter(
#         y=df.loc['2024-01-01':, feature],
#         x=df.loc['2024-01-01':,:].index,
#         name=feature,
#         marker_color="black"
#     ), row=1, col=1)

#     fig.add_trace(go.Scatter(
#         y=df.loc['2024-01-01':, f'new_mean_{fname}_3_days'],
#         x=df.loc['2024-01-01':,:].index,
#         name=f'new_mean_{fname}_3_days',
#         marker_color="blue"
#     ), row=1, col=1)

#     fig.add_trace(go.Scatter(
#         y=df.loc['2024-01-01':, f'new_mean_{fname}_5_days'],
#         x=df.loc['2024-01-01':,:].index,
#         name=f'new_mean_{fname}_5_days',
#         marker_color="green"
#     ), row=1, col=1)

#     fig.add_trace(go.Scatter(
#         y=df.loc['2024-01-01':, f'new_mean_{fname}_7_days'],
#         x=df.loc['2024-01-01':,:].index,
#         name=f'new_mean_{fname}_7_days',
#         marker_color="magenta"
#     ), row=1, col=1)

#     fig.add_trace(go.Scatter(
#         y=df.loc['2024-01-01':, f'mean_{fname}'],
#         x=df.loc['2024-01-01':,:].index,
#         name=f'mean_{fname}',
#         marker_color="red"
#     ), row=1, col=1)

#     fig.update_layout(
#         title=f'Means of {feature.title()}', 
#         xaxis_tickangle=-45,
#         width=1300,
#         height=1000,
#         hovermode="x"
#     )

#     fig.write_html(f'/masters_diploma/correlation_vizualizations/visualization_mean_{fname}.html')

# %%
df
# Out:
#                      temperature  relative_humidity  dew_point  precipitation  \
# date
# 2020-01-01 00:00:00          1.5                 94        0.6            0.6
# 2020-01-01 01:00:00          1.0                 95        0.4            0.3
# 2020-01-01 02:00:00          1.5                 93        0.5            0.2
# 2020-01-01 03:00:00          1.5                 92        0.4            0.1
# 2020-01-01 04:00:00          1.0                 94        0.2            0.2
# ...                          ...                ...        ...            ...
# 2025-01-16 20:00:00          0.7                 92       -0.4            0.0
# 2025-01-16 21:00:00          0.7                 91       -0.5            0.0
# 2025-01-16 22:00:00          0.8                 90       -0.6            0.0
# 2025-01-16 23:00:00          0.6                 90       -0.8            0.0
# 2025-01-17 00:00:00          0.6                 89       -1.0            0.0
#
#                      rain  snowfall  weather_code  pressure_msl  \
# date
# 2020-01-01 00:00:00   0.1      0.35            73        1009.8
# 2020-01-01 01:00:00   0.3      0.00            51        1010.4
# 2020-01-01 02:00:00   0.2      0.00            51        1010.8
# 2020-01-01 03:00:00   0.1      0.00            51        1011.7
# 2020-01-01 04:00:00   0.2      0.00            51        1012.8
# ...                   ...       ...           ...           ...
# 2025-01-16 20:00:00   0.0      0.00             3        1030.3
# 2025-01-16 21:00:00   0.0      0.00             3        1030.3
# 2025-01-16 22:00:00   0.0      0.00             3        1030.0
# 2025-01-16 23:00:00   0.0      0.00             3        1029.6
# 2025-01-17 00:00:00   0.0      0.00             3        1029.4
#
#                      surface_pressure  cloud_cover  ...  \
# date                                                ...
# 2020-01-01 00:00:00             986.5           97  ...
# 2020-01-01 01:00:00             987.1          100  ...
# 2020-01-01 02:00:00             987.5          100  ...
# 2020-01-01 03:00:00             988.4          100  ...
# 2020-01-01 04:00:00             989.4          100  ...
# ...                               ...          ...  ...
# 2025-01-16 20:00:00            1006.5          100  ...
# 2025-01-16 21:00:00            1006.5          100  ...
# 2025-01-16 22:00:00            1006.2           97  ...
# 2025-01-16 23:00:00            1005.8           88  ...
# 2025-01-17 00:00:00            1005.6          100  ...
#
#                      new_mean_cloud_5_days  new_mean_cloud_7_days  \
# date
# 2020-01-01 00:00:00                    NaN                    NaN
# 2020-01-01 01:00:00                    NaN                    NaN
# 2020-01-01 02:00:00                    NaN                    NaN
# 2020-01-01 03:00:00                    NaN                    NaN
# 2020-01-01 04:00:00                    NaN                    NaN
# ...                                    ...                    ...
# 2025-01-16 20:00:00                  81.00                  85.26
# 2025-01-16 21:00:00                  79.96                  84.17
# 2025-01-16 22:00:00                  82.64                  83.94
# 2025-01-16 23:00:00                  81.20                  82.89
# 2025-01-17 00:00:00                  81.00                  83.11
#
#                      mean_wspeed  new_mean_wspeed_3_days  \
# date
# 2020-01-01 00:00:00          NaN                     NaN
# 2020-01-01 01:00:00          NaN                     NaN
# 2020-01-01 02:00:00          NaN                     NaN
# 2020-01-01 03:00:00          NaN                     NaN
# 2020-01-01 04:00:00          NaN                     NaN
# ...                          ...                     ...
# 2025-01-16 20:00:00        13.30                   14.69
# 2025-01-16 21:00:00        13.38                   14.24
# 2025-01-16 22:00:00        13.90                   14.63
# 2025-01-16 23:00:00        14.08                   14.62
# 2025-01-17 00:00:00        15.04                   14.48
#
#                      new_mean_wspeed_5_days  new_mean_wspeed_7_days  \
# date
# 2020-01-01 00:00:00                     NaN                     NaN
# 2020-01-01 01:00:00                     NaN                     NaN
# 2020-01-01 02:00:00                     NaN                     NaN
# 2020-01-01 03:00:00                     NaN                     NaN
# 2020-01-01 04:00:00                     NaN                     NaN
# ...                                     ...                     ...
# 2025-01-16 20:00:00                   14.36                   13.77
# 2025-01-16 21:00:00                   14.15                   13.45
# 2025-01-16 22:00:00                   14.42                   13.50
# 2025-01-16 23:00:00                   14.36                   13.58
# 2025-01-17 00:00:00                   13.93                   13.26
#
#                      mean_wdir  new_mean_wdir_3_days  new_mean_wdir_5_days  \
# date
# 2020-01-01 00:00:00        NaN                   NaN                   NaN
# 2020-01-01 01:00:00        NaN                   NaN                   NaN
# 2020-01-01 02:00:00        NaN                   NaN                   NaN
# 2020-01-01 03:00:00        NaN                   NaN                   NaN
# 2020-01-01 04:00:00        NaN                   NaN                   NaN
# ...                        ...                   ...                   ...
# 2025-01-16 20:00:00      242.2                239.40                237.96
# 2025-01-16 21:00:00      242.2                237.40                240.76
# 2025-01-16 22:00:00      244.8                237.60                241.20
# 2025-01-16 23:00:00      249.8                238.73                242.60
# 2025-01-17 00:00:00      245.2                237.13                243.40
#
#                      new_mean_wdir_7_days
# date
# 2020-01-01 00:00:00                   NaN
# 2020-01-01 01:00:00                   NaN
# 2020-01-01 02:00:00                   NaN
# 2020-01-01 03:00:00                   NaN
# 2020-01-01 04:00:00                   NaN
# ...                                   ...
# 2025-01-16 20:00:00                240.80
# 2025-01-16 21:00:00                242.03
# 2025-01-16 22:00:00                241.89
# 2025-01-16 23:00:00                240.40
# 2025-01-17 00:00:00                240.86
#
# [44233 rows x 372 columns]

# %%
list(df.columns)
# Out:
# ['temperature',
#  'relative_humidity',
#  'dew_point',
#  'precipitation',
#  'rain',
#  'snowfall',
#  'weather_code',
#  'pressure_msl',
#  'surface_pressure',
#  'cloud_cover',
#  'wind_speed',
#  'wind_direction',
#  'is_day',
#  'sunshine_duration',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'week_day',
#  'year_day',
#  'temperature_max_3_days',
#  'temperature_min_3_days',
#  'temperature_mean_3_days',
#  'temperature_max_5_days',
#  'temperature_min_5_days',
#  'temperature_mean_5_days',
#  'temperature_max_7_days',
#  'temperature_min_7_days',
#  'temperature_mean_7_days',
#  'temperature_max_3_weeks',
#  'temperature_min_3_weeks',
#  'temperature_mean_3_weeks',
#  'temperature_max_5_weeks',
#  'temperature_min_5_weeks',
#  'temperature_mean_5_weeks',
#  'temperature_max_7_weeks',
#  'temperature_min_7_weeks',
#  'temperature_mean_7_weeks',
#  'temperature_max_3_years',
#  'temperature_min_3_years',
#  'temperature_mean_3_years',
#  'temperature_max_4_years',
#  'temperature_min_4_years',
#  'temperature_mean_4_years',
#  'temperature_lag_24',
#  'temperature_lag_48',
#  'temperature_lag_72',
#  'relative_humidity_max_3_days',
#  'relative_humidity_min_3_days',
#  'relative_humidity_mean_3_days',
#  'relative_humidity_max_5_days',
#  'relative_humidity_min_5_days',
#  'relative_humidity_mean_5_days',
#  'relative_humidity_max_7_days',
#  'relative_humidity_min_7_days',
#  'relative_humidity_mean_7_days',
#  'relative_humidity_max_3_weeks',
#  'relative_humidity_min_3_weeks',
#  'relative_humidity_mean_3_weeks',
#  'relative_humidity_max_5_weeks',
#  'relative_humidity_min_5_weeks',
#  'relative_humidity_mean_5_weeks',
#  'relative_humidity_max_7_weeks',
#  'relative_humidity_min_7_weeks',
#  'relative_humidity_mean_7_weeks',
#  'relative_humidity_max_3_years',
#  'relative_humidity_min_3_years',
#  'relative_humidity_mean_3_years',
#  'relative_humidity_max_4_years',
#  'relative_humidity_min_4_years',
#  'relative_humidity_mean_4_years',
#  'relative_humidity_lag_24',
#  'relative_humidity_lag_48',
#  'relative_humidity_lag_72',
#  'dew_point_max_3_days',
#  'dew_point_min_3_days',
#  'dew_point_mean_3_days',
#  'dew_point_max_5_days',
#  'dew_point_min_5_days',
#  'dew_point_mean_5_days',
#  'dew_point_max_7_days',
#  'dew_point_min_7_days',
#  'dew_point_mean_7_days',
#  'dew_point_max_3_weeks',
#  'dew_point_min_3_weeks',
#  'dew_point_mean_3_weeks',
#  'dew_point_max_5_weeks',
#  'dew_point_min_5_weeks',
#  'dew_point_mean_5_weeks',
#  'dew_point_max_7_weeks',
#  'dew_point_min_7_weeks',
#  'dew_point_mean_7_weeks',
#  'dew_point_max_3_years',
#  'dew_point_min_3_years',
#  'dew_point_mean_3_years',
#  'dew_point_max_4_years',
#  'dew_point_min_4_years',
#  'dew_point_mean_4_years',
#  'dew_point_lag_24',
#  'dew_point_lag_48',
#  'dew_point_lag_72',
#  'precipitation_max_3_days',
#  'precipitation_min_3_days',
#  'precipitation_mean_3_days',
#  'precipitation_max_5_days',
#  'precipitation_min_5_days',
#  'precipitation_mean_5_days',
#  'precipitation_max_7_days',
#  'precipitation_min_7_days',
#  'precipitation_mean_7_days',
#  'precipitation_max_3_weeks',
#  'precipitation_min_3_weeks',
#  'precipitation_mean_3_weeks',
#  'precipitation_max_5_weeks',
#  'precipitation_min_5_weeks',
#  'precipitation_mean_5_weeks',
#  'precipitation_max_7_weeks',
#  'precipitation_min_7_weeks',
#  'precipitation_mean_7_weeks',
#  'precipitation_max_3_years',
#  'precipitation_min_3_years',
#  'precipitation_mean_3_years',
#  'precipitation_max_4_years',
#  'precipitation_min_4_years',
#  'precipitation_mean_4_years',
#  'precipitation_lag_24',
#  'precipitation_lag_48',
#  'precipitation_lag_72',
#  'rain_max_3_days',
#  'rain_min_3_days',
#  'rain_mean_3_days',
#  'rain_max_5_days',
#  'rain_min_5_days',
#  'rain_mean_5_days',
#  'rain_max_7_days',
#  'rain_min_7_days',
#  'rain_mean_7_days',
#  'rain_max_3_weeks',
#  'rain_min_3_weeks',
#  'rain_mean_3_weeks',
#  'rain_max_5_weeks',
#  'rain_min_5_weeks',
#  'rain_mean_5_weeks',
#  'rain_max_7_weeks',
#  'rain_min_7_weeks',
#  'rain_mean_7_weeks',
#  'rain_max_3_years',
#  'rain_min_3_years',
#  'rain_mean_3_years',
#  'rain_max_4_years',
#  'rain_min_4_years',
#  'rain_mean_4_years',
#  'rain_lag_24',
#  'rain_lag_48',
#  'rain_lag_72',
#  'snowfall_max_3_days',
#  'snowfall_min_3_days',
#  'snowfall_mean_3_days',
#  'snowfall_max_5_days',
#  'snowfall_min_5_days',
#  'snowfall_mean_5_days',
#  'snowfall_max_7_days',
#  'snowfall_min_7_days',
#  'snowfall_mean_7_days',
#  'snowfall_max_3_weeks',
#  'snowfall_min_3_weeks',
#  'snowfall_mean_3_weeks',
#  'snowfall_max_5_weeks',
#  'snowfall_min_5_weeks',
#  'snowfall_mean_5_weeks',
#  'snowfall_max_7_weeks',
#  'snowfall_min_7_weeks',
#  'snowfall_mean_7_weeks',
#  'snowfall_max_3_years',
#  'snowfall_min_3_years',
#  'snowfall_mean_3_years',
#  'snowfall_max_4_years',
#  'snowfall_min_4_years',
#  'snowfall_mean_4_years',
#  'snowfall_lag_24',
#  'snowfall_lag_48',
#  'snowfall_lag_72',
#  'pressure_msl_max_3_days',
#  'pressure_msl_min_3_days',
#  'pressure_msl_mean_3_days',
#  'pressure_msl_max_5_days',
#  'pressure_msl_min_5_days',
#  'pressure_msl_mean_5_days',
#  'pressure_msl_max_7_days',
#  'pressure_msl_min_7_days',
#  'pressure_msl_mean_7_days',
#  'pressure_msl_max_3_weeks',
#  'pressure_msl_min_3_weeks',
#  'pressure_msl_mean_3_weeks',
#  'pressure_msl_max_5_weeks',
#  'pressure_msl_min_5_weeks',
#  'pressure_msl_mean_5_weeks',
#  'pressure_msl_max_7_weeks',
#  'pressure_msl_min_7_weeks',
#  'pressure_msl_mean_7_weeks',
#  'pressure_msl_max_3_years',
#  'pressure_msl_min_3_years',
#  'pressure_msl_mean_3_years',
#  'pressure_msl_max_4_years',
#  'pressure_msl_min_4_years',
#  'pressure_msl_mean_4_years',
#  'pressure_msl_lag_24',
#  'pressure_msl_lag_48',
#  'pressure_msl_lag_72',
#  'surface_pressure_max_3_days',
#  'surface_pressure_min_3_days',
#  'surface_pressure_mean_3_days',
#  'surface_pressure_max_5_days',
#  'surface_pressure_min_5_days',
#  'surface_pressure_mean_5_days',
#  'surface_pressure_max_7_days',
#  'surface_pressure_min_7_days',
#  'surface_pressure_mean_7_days',
#  'surface_pressure_max_3_weeks',
#  'surface_pressure_min_3_weeks',
#  'surface_pressure_mean_3_weeks',
#  'surface_pressure_max_5_weeks',
#  'surface_pressure_min_5_weeks',
#  'surface_pressure_mean_5_weeks',
#  'surface_pressure_max_7_weeks',
#  'surface_pressure_min_7_weeks',
#  'surface_pressure_mean_7_weeks',
#  'surface_pressure_max_3_years',
#  'surface_pressure_min_3_years',
#  'surface_pressure_mean_3_years',
#  'surface_pressure_max_4_years',
#  'surface_pressure_min_4_years',
#  'surface_pressure_mean_4_years',
#  'surface_pressure_lag_24',
#  'surface_pressure_lag_48',
#  'surface_pressure_lag_72',
#  'cloud_cover_max_3_days',
#  'cloud_cover_min_3_days',
#  'cloud_cover_mean_3_days',
#  'cloud_cover_max_5_days',
#  'cloud_cover_min_5_days',
#  'cloud_cover_mean_5_days',
#  'cloud_cover_max_7_days',
#  'cloud_cover_min_7_days',
#  'cloud_cover_mean_7_days',
#  'cloud_cover_max_3_weeks',
#  'cloud_cover_min_3_weeks',
#  'cloud_cover_mean_3_weeks',
#  'cloud_cover_max_5_weeks',
#  'cloud_cover_min_5_weeks',
#  'cloud_cover_mean_5_weeks',
#  'cloud_cover_max_7_weeks',
#  'cloud_cover_min_7_weeks',
#  'cloud_cover_mean_7_weeks',
#  'cloud_cover_max_3_years',
#  'cloud_cover_min_3_years',
#  'cloud_cover_mean_3_years',
#  'cloud_cover_max_4_years',
#  'cloud_cover_min_4_years',
#  'cloud_cover_mean_4_years',
#  'cloud_cover_lag_24',
#  'cloud_cover_lag_48',
#  'cloud_cover_lag_72',
#  'wind_speed_max_3_days',
#  'wind_speed_min_3_days',
#  'wind_speed_mean_3_days',
#  'wind_speed_max_5_days',
#  'wind_speed_min_5_days',
#  'wind_speed_mean_5_days',
#  'wind_speed_max_7_days',
#  'wind_speed_min_7_days',
#  'wind_speed_mean_7_days',
#  'wind_speed_max_3_weeks',
#  'wind_speed_min_3_weeks',
#  'wind_speed_mean_3_weeks',
#  'wind_speed_max_5_weeks',
#  'wind_speed_min_5_weeks',
#  'wind_speed_mean_5_weeks',
#  'wind_speed_max_7_weeks',
#  'wind_speed_min_7_weeks',
#  'wind_speed_mean_7_weeks',
#  'wind_speed_max_3_years',
#  'wind_speed_min_3_years',
#  'wind_speed_mean_3_years',
#  'wind_speed_max_4_years',
#  'wind_speed_min_4_years',
#  'wind_speed_mean_4_years',
#  'wind_speed_lag_24',
#  'wind_speed_lag_48',
#  'wind_speed_lag_72',
#  'wind_direction_max_3_days',
#  'wind_direction_min_3_days',
#  'wind_direction_mean_3_days',
#  'wind_direction_max_5_days',
#  'wind_direction_min_5_days',
#  'wind_direction_mean_5_days',
#  'wind_direction_max_7_days',
#  'wind_direction_min_7_days',
#  'wind_direction_mean_7_days',
#  'wind_direction_max_3_weeks',
#  'wind_direction_min_3_weeks',
#  'wind_direction_mean_3_weeks',
#  'wind_direction_max_5_weeks',
#  'wind_direction_min_5_weeks',
#  'wind_direction_mean_5_weeks',
#  'wind_direction_max_7_weeks',
#  'wind_direction_min_7_weeks',
#  'wind_direction_mean_7_weeks',
#  'wind_direction_max_3_years',
#  'wind_direction_min_3_years',
#  'wind_direction_mean_3_years',
#  'wind_direction_max_4_years',
#  'wind_direction_min_4_years',
#  'wind_direction_mean_4_years',
#  'wind_direction_lag_24',
#  'wind_direction_lag_48',
#  'wind_direction_lag_72',
#  'sunshine_duration_max_3_days',
#  'sunshine_duration_min_3_days',
#  'sunshine_duration_mean_3_days',
#  'sunshine_duration_max_5_days',
#  'sunshine_duration_min_5_days',
#  'sunshine_duration_mean_5_days',
#  'sunshine_duration_max_7_days',
#  'sunshine_duration_min_7_days',
#  'sunshine_duration_mean_7_days',
#  'sunshine_duration_max_3_weeks',
#  'sunshine_duration_min_3_weeks',
#  'sunshine_duration_mean_3_weeks',
#  'sunshine_duration_max_5_weeks',
#  'sunshine_duration_min_5_weeks',
#  'sunshine_duration_mean_5_weeks',
#  'sunshine_duration_max_7_weeks',
#  'sunshine_duration_min_7_weeks',
#  'sunshine_duration_mean_7_weeks',
#  'sunshine_duration_max_3_years',
#  'sunshine_duration_min_3_years',
#  'sunshine_duration_mean_3_years',
#  'sunshine_duration_max_4_years',
#  'sunshine_duration_min_4_years',
#  'sunshine_duration_mean_4_years',
#  'sunshine_duration_lag_24',
#  'sunshine_duration_lag_48',
#  'sunshine_duration_lag_72',
#  'mean_temp',
#  'new_mean_temp_3_days',
#  'new_mean_temp_5_days',
#  'new_mean_temp_7_days',
#  'mean_humid',
#  'new_mean_humid_3_days',
#  'new_mean_humid_5_days',
#  'new_mean_humid_7_days',
#  'mean_precip',
#  'new_mean_precip_3_days',
#  'new_mean_precip_5_days',
#  'new_mean_precip_7_days',
#  'mean_pres',
#  'new_mean_pres_3_days',
#  'new_mean_pres_5_days',
#  'new_mean_pres_7_days',
#  'mean_cloud',
#  'new_mean_cloud_3_days',
#  'new_mean_cloud_5_days',
#  'new_mean_cloud_7_days',
#  'mean_wspeed',
#  'new_mean_wspeed_3_days',
#  'new_mean_wspeed_5_days',
#  'new_mean_wspeed_7_days',
#  'mean_wdir',
#  'new_mean_wdir_3_days',
#  'new_mean_wdir_5_days',
#  'new_mean_wdir_7_days']

# %%
_1 = df.loc['2024-01-01':, ['temperature', 'new_mean_temp_3_days', 'new_mean_temp_5_days', 'new_mean_temp_7_days', 'mean_temp']]

_2 = pd.DataFrame(None, index=_1.index)
for col in _1.columns[1:]:
    _2.loc[:, col] = abs(_1.loc[:, col] - _1.loc[:, 'temperature'])
    
_3 = pd.DataFrame(index=_2.index, columns=_2.columns)
for row in _2.index:
    min_col = _2.loc[row, :].idxmin()  # Get the column with the minimum value
    for col in _3.columns:
        _3.loc[row, col] = 1 if col == min_col else 0  # Assign 1 if it's the min column, otherwise 0

_3
# Out:
#                     new_mean_temp_3_days new_mean_temp_5_days  \
# date
# 2024-01-01 00:00:00                    0                    0
# 2024-01-01 01:00:00                    0                    0
# 2024-01-01 02:00:00                    0                    0
# 2024-01-01 03:00:00                    0                    0
# 2024-01-01 04:00:00                    0                    0
# ...                                  ...                  ...
# 2025-01-16 20:00:00                    0                    0
# 2025-01-16 21:00:00                    0                    0
# 2025-01-16 22:00:00                    0                    0
# 2025-01-16 23:00:00                    0                    0
# 2025-01-17 00:00:00                    0                    0
#
#                     new_mean_temp_7_days mean_temp
# date
# 2024-01-01 00:00:00                    1         0
# 2024-01-01 01:00:00                    1         0
# 2024-01-01 02:00:00                    1         0
# 2024-01-01 03:00:00                    1         0
# 2024-01-01 04:00:00                    1         0
# ...                                  ...       ...
# 2025-01-16 20:00:00                    1         0
# 2025-01-16 21:00:00                    1         0
# 2025-01-16 22:00:00                    1         0
# 2025-01-16 23:00:00                    1         0
# 2025-01-17 00:00:00                    1         0
#
# [9169 rows x 4 columns]

# %%
_3.sum()
# Out:
# new_mean_temp_3_days    1636
# new_mean_temp_5_days    1383
# new_mean_temp_7_days    3225
# mean_temp               2925
# dtype: object

# %%
df.to_csv('/masters_diploma/processed_data/history_weather.csv')
