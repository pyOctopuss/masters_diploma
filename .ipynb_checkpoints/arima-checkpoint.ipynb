# %%
import pandas as pd
from datetime import datetime

from pmdarima.arima.utils import ndiffs, nsdiffs
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import matplotlib.pyplot as plt

# %%
path = f"/masters_diploma/processed_data/history_weather.csv"

full_set = pd.read_csv(
    path,
    parse_dates=["date"],
    index_col=["date"],
)

# %%
full_set
# Out:
#                      temperature  relative_humidity  dew_point  precipitation  \
# date
# 2015-01-01 00:00:00         -5.9               56.0      -13.3            0.0
# 2015-01-01 01:00:00         -5.5               59.0      -12.4            0.0
# 2015-01-01 02:00:00         -5.2               63.0      -11.2            0.0
# 2015-01-01 03:00:00         -4.9               68.0       -9.9            0.0
# 2015-01-01 04:00:00         -4.6               73.0       -8.7            0.0
# ...                          ...                ...        ...            ...
# 2025-09-25 19:00:00          0.0                0.0        0.0            0.0
# 2025-09-25 20:00:00          0.0                0.0        0.0            0.0
# 2025-09-25 21:00:00          0.0                0.0        0.0            0.0
# 2025-09-25 22:00:00          0.0                0.0        0.0            0.0
# 2025-09-25 23:00:00          0.0                0.0        0.0            0.0
#
#                      rain  snowfall  weather_code  pressure_msl  \
# date
# 2015-01-01 00:00:00   0.0      0.07          71.0        1026.1
# 2015-01-01 01:00:00   0.0      0.00           3.0        1025.1
# 2015-01-01 02:00:00   0.0      0.00           3.0        1024.7
# 2015-01-01 03:00:00   0.0      0.00           3.0        1024.3
# 2015-01-01 04:00:00   0.0      0.07          71.0        1024.1
# ...                   ...       ...           ...           ...
# 2025-09-25 19:00:00   0.0      0.00           0.0           0.0
# 2025-09-25 20:00:00   0.0      0.00           0.0           0.0
# 2025-09-25 21:00:00   0.0      0.00           0.0           0.0
# 2025-09-25 22:00:00   0.0      0.00           0.0           0.0
# 2025-09-25 23:00:00   0.0      0.00           0.0           0.0
#
#                      surface_pressure  cloud_cover  ...  \
# date                                                ...
# 2015-01-01 00:00:00            1001.8        100.0  ...
# 2015-01-01 01:00:00            1000.8         97.0  ...
# 2015-01-01 02:00:00            1000.5        100.0  ...
# 2015-01-01 03:00:00            1000.1         99.0  ...
# 2015-01-01 04:00:00            1000.0         98.0  ...
# ...                               ...          ...  ...
# 2025-09-25 19:00:00               0.0          0.0  ...
# 2025-09-25 20:00:00               0.0          0.0  ...
# 2025-09-25 21:00:00               0.0          0.0  ...
# 2025-09-25 22:00:00               0.0          0.0  ...
# 2025-09-25 23:00:00               0.0          0.0  ...
#
#                      sunshine_duration_max_3_years  \
# date
# 2015-01-01 00:00:00                            0.0
# 2015-01-01 01:00:00                            0.0
# 2015-01-01 02:00:00                            0.0
# 2015-01-01 03:00:00                            0.0
# 2015-01-01 04:00:00                            0.0
# ...                                            ...
# 2025-09-25 19:00:00                            0.0
# 2025-09-25 20:00:00                            0.0
# 2025-09-25 21:00:00                            0.0
# 2025-09-25 22:00:00                            0.0
# 2025-09-25 23:00:00                            0.0
#
#                      sunshine_duration_min_3_years  \
# date
# 2015-01-01 00:00:00                            0.0
# 2015-01-01 01:00:00                            0.0
# 2015-01-01 02:00:00                            0.0
# 2015-01-01 03:00:00                            0.0
# 2015-01-01 04:00:00                        0.0
# ...                                        ...
# 2025-09-25 19:00:00                        0.0
# 2025-09-25 20:00:00                        0.0
# 2025-09-25 21:00:00                        0.0
# 2025-09-25 22:00:00                        0.0
# 2025-09-25 23:00:00                        0.0
#
# [94104 rows x 356 columns]

# %%
temp = full_set['temperature']
exog = full_set[['month', 'year_day', 'is_day', 'sunshine_duration', 'temperature_min_3_weeks', 'temperature_max_3_weeks', 'temperature_mean_3_weeks',
         'temperature_min_3_years', 'temperature_max_3_years', 'temperature_mean_3_years', 'cloud_cover_mean_7_days', 'pressure_msl_mean_7_days']]

temp = temp.asfreq(pd.infer_freq(temp.index) or "H")
exog = exog.reindex(temp.index).interpolate(limit_direction="both")

# %%
train_start = datetime(2023, 9, 1, 0)
train_end = datetime(2025, 8, 31, 23)
test_start = datetime(2025, 9, 1, 0)
test_end = datetime(2025, 9, 14, 23)

# %%
X_train = exog.loc[train_start: train_end]
X_test = exog.loc[test_start: test_end]

y_train = temp.loc[train_start: train_end]
y_test = temp.loc[test_start: test_end]

# %%
d = ndiffs(temp, alpha=0.05, test='kpss')
D = nsdiffs(temp, m=24, max_D=1, test='ocsb') 

d, D
# Out:
# (1, 0)

# %%
model_arima = ARIMA(y_train, order=(2, 1, 3))
result_arima = model_arima.fit()

ar_forecast = result_arima.forecast(steps=len(y_test))
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_sarimax = SARIMAX(y_train, exog=X_train, order=(1, 1, 1), seasonal_order=(1, 0, 1, 24))
result_sarimax = model_sarimax.fit(disp=False)

sar_forecast = result_sarimax.get_forecast(steps=len(y_test), exog=X_test).predicted_mean

# %%
plt.figure(figsize=(10,5))
plt.plot(y_train.loc['2025-09-13':], label="Train")
plt.plot(y_test, label="Test", color="orange")
plt.plot(ar_forecast, label="Forecast", color="red")
plt.plot(sar_forecast, label="Forecast", color="magenta")
plt.legend()
plt.show()

# %%
from pmdarima import auto_arima

# ARIMA (no seasonality, no exog)
arima_auto = auto_arima(
    y_train, seasonal=False, d=None, max_p=3, max_q=3,
    stepwise=True, information_criterion='aic', trace=False
)
print("ARIMA order:", arima_auto.order)

# SARIMAX (with seasonality and exog)
s = 24  # e.g., hourly data -> daily seasonality
sarimax_auto = auto_arima(
    y_train, X=X_train, seasonal=True, m=s,
    d=None, D=None, max_p=3, max_q=3, max_P=2, max_Q=2,
    stepwise=True, information_criterion='aic', trace=False
)
print("SARIMAX order:", sarimax_auto.order, "seasonal:", sarimax_auto.seasonal_order)
# Out:
# ARIMA order: (2, 1, 3)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 12
#      10 # SARIMAX (with seasonality and exog)
#      11 s = 24  # e.g., hourly data -> daily seasonality
# ---> 12 sarimax_auto = auto_arima(
#      13     y_train, X=X_train, seasonal=True, m=s,
#      14     d=None, D=None, max_p=3, max_q=3, max_P=2, max_Q=2,
#      15     stepwise=True, information_criterion='aic', trace=False
#      16 )
#      17 print("SARIMAX order:", sarimax_auto.order, "seasonal:", sarimax_auto.seasonal_order)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\auto.py:701, in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     669     # init the stepwise model wrapper
#     670     search = solvers._StepwiseFitWrapper(
#     671         y,
#     672         X=X,
#    (...)
#     698         **sarimax_kwargs,
#     699     )
# --> 701 sorted_res = search.solve()
#     702 return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\_auto_solvers.py:347, in _StepwiseFitWrapper.solve(self)
#     342     Q -= 1
#     343     continue
#     345 if P < max_P and \
#     346         self.k < self.max_k and \
# --> 347         self._do_fit((p, d, q), (P + 1, D, Q, m)):
#     348     P += 1
#     349     continue
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\_auto_solvers.py:235, in _StepwiseFitWrapper._do_fit(self, order, seasonal_order, constant)
#     230 if (order, seasonal_order, constant) not in self.results_dict:
#     231
#     232     # increment the number of fits
#     233     self.k += 1
# --> 235     fit, fit_time, new_ic = self._fit_arima(
#     236         order=order,
#     237         seasonal_order=seasonal_order,
#     238         with_intercept=constant)
#     240     # use the orders as a key to be hashed for
#     241     # the dictionary (pointing to fit)
#     242     self.results_dict[(order, seasonal_order, constant)] = fit
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\_auto_solvers.py:508, in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     500 fit = ARIMA(order=order, seasonal_order=seasonal_order,
#     501             start_params=start_params, trend=trend, method=method,
#     502             maxiter=maxiter, suppress_warnings=suppress_warnings,
#     503             out_of_sample_size=out_of_sample_size, scoring=scoring,
#     504             scoring_args=scoring_args,
#     505             with_intercept=with_intercept, **kwargs)
#     507 try:
# --> 508     fit.fit(y, X=X, **fit_params)
#     510 # for non-stationarity errors or singular matrices, return None
#     511 except (LinAlgError, ValueError) as v:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\arima.py:603, in ARIMA.fit(self, y, X, **fit_args)
#     600         X = safe_indexing(X, slice(0, n_exog - cv))
#     602 # Internal call
# --> 603 self._fit(y, X, **fit_args)
#     605 # now make a forecast if we're validating to compute the
#     606 # out-of-sample score
#     607 if cv_samples is not None:
#     608     # get the predictions (use self.predict, which calls forecast
#     609     # from statsmodels internally)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\arima.py:524, in ARIMA._fit(self, y, X, **fit_args)
#     522     with warnings.catch_warnings(record=False):
#     523         warnings.simplefilter('ignore')
# --> 524         fit, self.arima_res_ = _fit_wrapper()
#     525 else:
#     526     fit, self.arima_res_ = _fit_wrapper()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\arima.py:510, in ARIMA._fit.<locals>._fit_wrapper()
#     507 _maxiter = fit_args.pop("maxiter", _maxiter)
#     509 disp = fit_args.pop("disp", 0)
# --> 510 fitted = arima.fit(
#     511     start_params=start_params,
#     512     method=method,
#     513     maxiter=_maxiter,
#     514     disp=disp,
#     515     **fit_args,
#     516 )
#     518 return arima, fitted
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:729, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     727 else:
#     728     func = self.smooth
# --> 729 res = func(mlefit.params, transformed=False, includes_fixed=False,
#     730            cov_type=cov_type, cov_kwds=cov_kwds)
#     732 res.mlefit = mlefit
#     733 res.mle_retvals = mlefit.mle_retvals
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:887, in MLEModel.smooth(self, params, transformed, includes_fixed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     884     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     886 # Get the state space output
# --> 887 result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     889 # Wrap in a results object
#     890 return self._wrap_results(params, result, return_ssm, cov_type,
#     891                           cov_kwds, results_class,
#     892                           results_wrapper_class)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py:419, in KalmanSmoother.smooth(self, smoother_output, smooth_method, results, run_filter, prefix, complex_step, update_representation, update_filter, update_smoother, **kwargs)
#     417 if smoother_output is None:
#     418     smoother_output = self.smoother_output
# --> 419 smoother = self._smooth(smoother_output, results=results, **kwargs)
#     421 # Update the results
#     422 if update_smoother:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py:355, in KalmanSmoother._smooth(self, smoother_output, smooth_method, prefix, complex_step, results, **kwargs)
#     351 def _smooth(self, smoother_output=None, smooth_method=None, prefix=None,
#     352             complex_step=False, results=None, **kwargs):
#     353     # Initialize the smoother
#     354     prefix, dtype, create_smoother, create_filter, create_statespace = (
# --> 355         self._initialize_smoother(
#     356             smoother_output, smooth_method, prefix=prefix, **kwargs
#     357         ))
#     359     # Check that the filter and statespace weren't just recreated
#     360     if create_filter or create_statespace:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py:179, in KalmanSmoother._initialize_smoother(self, smoother_output, smooth_method, prefix, **kwargs)
#     176 if create_smoother:
#     177     # Setup the smoother
#     178     cls = self.prefix_kalman_smoother_map[prefix]
# --> 179     self._kalman_smoothers[prefix] = cls(
#     180         self._statespaces[prefix], self._kalman_filters[prefix],
#     181         smoother_output, smooth_method
#     182     )
#     183 # Otherwise, update the smoother parameters
#     184 else:
#     185     self._kalman_smoothers[prefix].set_smoother_output(
#     186         smoother_output, False)
#
# File statsmodels/tsa/statespace/_kalman_smoother.pyx:964, in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.__init__()
#
# File statsmodels/tsa/statespace/_kalman_smoother.pyx:1134, in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.set_smoother_output()
#
# File statsmodels/tsa/statespace/_kalman_smoother.pyx:1168, in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.reset()
#
# File statsmodels/tsa/statespace/_kalman_smoother.pyx:1121, in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.reset_filter_method()
#
# File statsmodels/tsa/statespace/_kalman_smoother.pyx:1004, in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.allocate_arrays()
#
# MemoryError: Unable to allocate 348. MiB for an array with shape (51, 51, 17544) and data type float64
